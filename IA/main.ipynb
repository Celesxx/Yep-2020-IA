# %% [markdown]
# # Ajout des dépendances

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib import rcParams

import tensorflow as tf
import numpy as np
import pandas as pd
import sys
import cv2

# %% [markdown]
# ## Loading d'une image

# %%
# %matplotlib inline
rcParams['figure.figsize'] = 11 ,8

def dataset(path):

    file_number = len(next(os.walk(path))[2])
    img_list_logo = []

    for filename in os.listdir(path):
        if filename.endswith(".jpg"):
            file = cv2.cvtColor(cv2.imread(path + filename), cv2.COLOR_BGR2RGB)
            img_list_logo.append(file)
        elif filename.endswith(".png"):
            file = cv2.cvtColor(cv2.imread(path + filename), cv2.COLOR_BGR2RGB)
            img_list_logo.append(file)
            
    return img_list_logo
        

def dataset_visualisation(dataset):

    print("data2", dataset)
    col = int(len(dataset) / 2)
    row = int(len(dataset) / col + (len(dataset) / col < 0) )
    
    print("len", len(dataset))
    print("col",col)
    print("row",row)
    if col * 2 != len(dataset):
        col = col + 1

    print("col",col)
    print("row",row)

    if len(dataset) <= 2:
        fig, ax = plt.subplots(1,col)
        print("1d")
    else: 
        fig, ax = plt.subplots(row, col)
        print("2d")

    r = 0
    c = 0
    ax[0].imshow(dataset[0])
    # for file in dataset:
    #     print("c", c)
    #     if len(dataset) <= 2:
    #         ax[c].imshow(dataset[c])
    #     else: 
    #         ax[r,c].imshow(file)

    #     c += 1
    #     if c == col:
    #         c = 0
    #         r += 1

        
dataset = dataset("../image/valide/")
print("data1", dataset)
fig, ax = plt.subplots(1,2)
# ax[0].imshow(dataset[0])
# ax[1].imshow(dataset[1])
dataset_visualisation(dataset)
# Out:
# data1 [array([[[237, 230, 214],
#         [237, 230, 214],
#         [237, 230, 214],
#         ...,
#         [230, 221, 206],
#         [229, 220, 205],
#         [228, 219, 204]],
#
#        [[237, 230, 214],
#         [237, 230, 214],
#         [237, 230, 214],
#         ...,
#         [229, 220, 205],
#         [229, 220, 205],
#         [228, 219, 204]],
#
#        [[237, 230, 214],
#         [237, 230, 214],
#         [237, 230, 214],
#         ...,
#         [228, 219, 204],
#         [228, 219, 204],
#         [228, 219, 204]],
#
#        ...,
#
#        [[238, 230, 209],
#         [238, 230, 209],
#         [238, 230, 209],
#         ...,
#         [227, 223, 211],
#         [226, 222, 210],
#         [225, 221, 209]],
#
#        [[238, 230, 209],
#         [238, 230, 209],
#         [238, 230, 209],
#         ...,
#         [227, 223, 211],
#         [226, 222, 210],
#         [226, 222, 210]],
#
#        [[237, 229, 208],
#         [237, 229, 208],
#         [238, 230, 209],
#         ...,
#         [227, 223, 211],
#         [227, 223, 211],
#         [226, 222, 210]]], dtype=uint8), array([[[246, 248, 245],
#         [246, 248, 245],
#         [246, 248, 245],
#         ...,
#         [238, 242, 241],
#         [238, 242, 241],
#         [238, 242, 241]],
#
#        [[246, 248, 245],
#         [246, 248, 245],
#         [246, 248, 245],
#         ...,
#         [238, 242, 241],
#         [238, 242, 241],
#         [238, 242, 241]],
#
#        [[246, 248, 245],
#         [246, 248, 245],
#         [245, 247, 244],
#         ...,
#         [238, 242, 241],
#         [238, 242, 241],
#         [238, 242, 241]],
#
#        ...,
#
#        [[194, 204, 196],
#         [195, 205, 197],
#         [195, 205, 197],
#         ...,
#         [225, 226, 218],
#         [225, 226, 218],
#         [225, 226, 218]],
#
#        [[194, 204, 196],
#         [195, 205, 197],
#         [195, 205, 197],
#         ...,
#         [225, 226, 218],
#         [225, 226, 218],
#         [225, 226, 218]],
#
#        [[194, 204, 196],
#         [195, 205, 197],
#         [195, 205, 197],
#         ...,
#         [225, 226, 218],
#         [225, 226, 218],
#         [225, 226, 218]]], dtype=uint8)]
# data2 [array([[[237, 230, 214],
#         [237, 230, 214],
#         [237, 230, 214],
#         ...,
#         [230, 221, 206],
#         [229, 220, 205],
#         [228, 219, 204]],
#
#        [[237, 230, 214],
#         [237, 230, 214],
#         [237, 230, 214],
#         ...,
#         [229, 220, 205],
#         [229, 220, 205],
#         [228, 219, 204]],
#
#        [[237, 230, 214],
#         [237, 230, 214],
#         [237, 230, 214],
#         ...,
#         [228, 219, 204],
#         [228, 219, 204],
#         [228, 219, 204]],
#
#        ...,
#
#        [[238, 230, 209],
#         [238, 230, 209],
#         [238, 230, 209],
#         ...,
#         [227, 223, 211],
#         [226, 222, 210],
#         [225, 221, 209]],
#
#        [[238, 230, 209],
#         [238, 230, 209],
#         [238, 230, 209],
#         ...,
#         [227, 223, 211],
#         [226, 222, 210],
#         [226, 222, 210]],
#
#        [[237, 229, 208],
#         [237, 229, 208],
#         [238, 230, 209],
#         ...,
#         [227, 223, 211],
#         [227, 223, 211],
#         [226, 222, 210]]], dtype=uint8), array([[[246, 248, 245],
#         [246, 248, 245],
#         [246, 248, 245],
#         ...,
#         [238, 242, 241],
#         [238, 242, 241],
#         [238, 242, 241]],
#
#        [[246, 248, 245],
#         [246, 248, 245],
#         [246, 248, 245],
#         ...,
#         [238, 242, 241],
#         [238, 242, 241],
#         [238, 242, 241]],
#
#        [[246, 248, 245],
#         [246, 248, 245],
#         [245, 247, 244],
#         ...,
#         [238, 242, 241],
#         [238, 242, 241],
#         [238, 242, 241]],
#
#        ...,
#
#        [[194, 204, 196],
#         [195, 205, 197],
#         [195, 205, 197],
#         ...,
#         [225, 226, 218],
#         [225, 226, 218],
#         [225, 226, 218]],
#
#        [[194, 204, 196],
#         [195, 205, 197],
#         [195, 205, 197],
#         ...,
#         [225, 226, 218],
#         [225, 226, 218],
#         [225, 226, 218]],
#
#        [[194, 204, 196],
#         [195, 205, 197],
#         [195, 205, 197],
#         ...,
#         [225, 226, 218],
#         [225, 226, 218],
#         [225, 226, 218]]], dtype=uint8)]
# len 2
# col 1
# row 2
# col 1
# row 2
# 1d
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-4f55a0038cb5> in <module>
#      61 # ax[0].imshow(dataset[0])
#      62 # ax[1].imshow(dataset[1])
# ---> 63 dataset_visualisation(dataset)
#
# <ipython-input-27-4f55a0038cb5> in dataset_visualisation(dataset)
#      42     r = 0
#      43     c = 0
# ---> 44     ax[0].imshow(dataset[0])
#      45     # for file in dataset:
#      46     #     print("c", c)
#
# TypeError: 'AxesSubplot' object is not subscriptable

# %%
result = []
for img in img_list:
    blurred_frame = cv2.GaussianBlur(img, (5, 5), 0)
    hsv = cv2.cvtColor(blurred_frame, cv2.COLOR_RGB2HSV)

    lower_blue = np.array([38, 86, 0])
    upper_blue = np.array([121, 255, 255])
    mask = cv2.inRange(hsv, lower_blue, upper_blue)
    contours, hierarchy = cv2.findContours(mask, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    result.append(cv2.drawContours(img, contours, -1, (0, 255, 0), 3))
#Histogramme

fig, ax = plt.subplots(2,2)
ax[0,0].imshow(result[0])
ax[0,1].imshow(result[1])
ax[1,0].imshow(result[2])
ax[1,1].imshow(result[3])

# %%
img_box1 =  cv2.cvtColor(cv2.imread('../image/blue.jpg'), cv2.COLOR_BGR2GRAY)
img_bottle1 = cv2.cvtColor(cv2.imread('../image/bottle.jpg'), cv2.COLOR_BGR2GRAY)
img_bouchon1 = cv2.cvtColor(cv2.imread('../image/bouchon.jpg'), cv2.COLOR_BGR2GRAY)
img_pince1 = cv2.cvtColor(cv2.imread('../image/pince.jpg'), cv2.COLOR_BGR2GRAY)
img_list1 = [img_box1, img_bottle1, img_bouchon1, img_pince1]

fig, ax = plt.subplots(2,2)
ax[0,0].imshow(img_list1[0])
ax[0,1].imshow(img_list1[1])
ax[1,0].imshow(img_list1[2])
ax[1,1].imshow(img_list1[3])

# %%
result = []
i = 0
for img in img_list1:
    _,mask1 = cv2.threshold(img,100,255,cv2.THRESH_BINARY)
    contours, hierarchy = cv2.findContours(mask1, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    result.append(cv2.drawContours(img_list[i], contours, -1, (0, 255, 0), 3))
    i += 1

fig, ax = plt.subplots(2,2)
ax[0,0].imshow(result[0])
ax[0,1].imshow(result[1])
ax[1,0].imshow(result[2])
ax[1,1].imshow(result[3])

# %%
img = cv2.imread('../image/logo1.jpg')
imgray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
ret, thresh = cv2.threshold(imgray, 127, 255, 0)
contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)
print("Number of contours = " + str(len(contours)))
print(contours[0])

logo_result = cv2.drawContours(img, contours, -1, (0, 255, 0), 3)
logo_result_0 = cv2.drawContours(cv2.imread('../image/logo1.jpg'), contours, 0, (0, 255, 0), 3)
logo_result_1 = cv2.drawContours(cv2.imread('../image/logo1.jpg'), contours, 1, (0, 255, 0), 3)
logo_result_gray = cv2.drawContours(imgray, contours, -1, (0, 255, 0), 3)


fig, ax = plt.subplots(2,2)
ax[0,0].imshow(logo_result)
ax[0,1].imshow(logo_result_gray)
ax[1,0].imshow(logo_result_0)
ax[1,1].imshow(logo_result_1)
# Out:
# Number of contours = 16
# [[[0 0]]
#
#  [[0 1]]
#
#  [[0 2]]
#
#  ...
#
#  [[3 0]]
#
#  [[2 0]]
#
#  [[1 0]]]

# %%
img_logo =  cv2.imread('../image/logo.png')
img_logo2 = cv2.imread('../image/logo1.jpg')
img_logo3 = cv2.imread('../image/logo2.png')
img_logo4 = cv2.imread('../image/logo4.jpg')
img_list2 = [img_logo, img_logo2, img_logo3, img_logo4]

fig, ax = plt.subplots(2,2)
ax[0,0].imshow(img_list2[0])
ax[0,1].imshow(img_list2[1])
ax[1,0].imshow(img_list2[2])
ax[1,1].imshow(img_list2[3])

# %%
result = []
for img_logo in img_list2:
    imgray = cv2.cvtColor(img_logo, cv2.COLOR_BGR2GRAY)
    ret, thresh = cv2.threshold(imgray, 127, 255, 0)
    contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)
    # print("Number of contours = " + str(len(contours)))
    # print(contours[0])

    logo_result = cv2.drawContours(img_logo, contours, -1, (0, 255, 0), 3)
    result.append(logo_result)

fig, ax = plt.subplots(2,2)
ax[0,0].imshow(result[0])
ax[0,1].imshow(result[1])
ax[1,0].imshow(result[2])
ax[1,1].imshow(result[3])

# %%
img_collier =  cv2.imread('../image/collier.jpg')
img_bague = cv2.imread('../image/bague.jpg')
img_socle = cv2.imread('../image/socle.jpg')
img_marine = cv2.imread('../image/marine.jpg')
img_trophee = cv2.imread('../image/trophee.jpg')
img_epitech = cv2.imread('../image/epitech.jpg')
img_list2 = [img_collier, img_bague, img_socle, img_marine, img_epitech, img_trophee]


fig, ax = plt.subplots(2,3)
ax[0,0].imshow(img_list2[0])
ax[0,1].imshow(img_list2[1])
ax[0,2].imshow(img_list2[2])
ax[1,0].imshow(img_list2[3])
ax[1,1].imshow(img_list2[4])
ax[1,2].imshow(img_list2[5])

# %%
result = []
for img_test in img_list2:
    imgray = cv2.cvtColor(img_test, cv2.COLOR_BGR2GRAY)
    ret, thresh = cv2.threshold(imgray, 127, 255, 0)
    contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)
    # print("Number of contours = " + str(len(contours)))
    # print(contours[0])

    logo_result = cv2.drawContours(img_test, contours, -1, (0, 255, 0), 3)
    result.append(logo_result)

fig, ax = plt.subplots(2,3)
ax[0,0].imshow(result[0])
ax[0,1].imshow(result[1])
ax[0,2].imshow(result[2])
ax[1,0].imshow(result[3])
ax[1,1].imshow(result[4])
ax[1,2].imshow(result[5])
